# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Using cached https://files.pythonhosted.org/packages/4c/aa/4e659d3ab6efe55c265d8159c845e9168e4c79045aef8e5460f9511cc3a7/gmaps-0.9.0.tar.gz
# Requirement already satisfied: ipython>=5.3.0 in f:\anaconda\lib\site-packages (from gmaps) (7.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in f:\anaconda\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.0 in f:\anaconda\lib\site-packages (from gmaps) (4.3.3)
# Collecting geojson>=2.0.0 (from gmaps)
#   Using cached https://files.pythonhosted.org/packages/e4/8d/9e28e9af95739e6d2d2f8d4bef0b3432da40b7c3588fbad4298c1be09e48/geojson-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six in f:\anaconda\lib\site-packages (from gmaps) (1.12.0)
# Requirement already satisfied: backcall in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (2.0.10)
# Requirement already satisfied: pickleshare in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: decorator in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.0)
# Requirement already satisfied: pygments in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (2.4.2)
# Requirement already satisfied: jedi>=0.10 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (0.15.1)
# Requirement already satisfied: setuptools>=18.5 in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (41.4.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in f:\anaconda\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in f:\anaconda\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in f:\anaconda\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.2)
# Requirement already satisfied: nbformat>=4.2.0 in f:\anaconda\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: ipython-genutils in f:\anaconda\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: wcwidth in f:\anaconda\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.7)
# Requirement already satisfied: parso>=0.5.0 in f:\anaconda\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.1)
# Requirement already satisfied: notebook>=4.4.1 in f:\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.1)
# Requirement already satisfied: jupyter-client in f:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.3)
# Requirement already satisfied: tornado>=4.2 in f:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-core in f:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in f:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.0.2)
# Requirement already satisfied: prometheus-client in f:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: Send2Trash in f:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in f:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (18.1.0)
# Requirement already satisfied: nbconvert in f:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.0)
# Requirement already satisfied: terminado>=0.8.1 in f:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.2)
# Requirement already satisfied: jinja2 in f:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.10.3)
# Requirement already satisfied: python-dateutil>=2.1 in f:\anaconda\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in f:\anaconda\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (223)
# Requirement already satisfied: pyrsistent>=0.14.0 in f:\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in f:\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in f:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: defusedxml in f:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: bleach in f:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in f:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in f:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in f:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in f:\anaconda\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: webencodings in f:\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py): started
#   Building wheel for gmaps (setup.py): finished with status 'done'
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076101 sha256=ac569446871e6ae2787decbddce28c646cd4c71bcc7635b123de60bb7aa6c62f
#   Stored in directory: C:\Users\hp\AppData\Local\pip\Cache\wheels\33\eb\41\5302168c36fc8ce8f48143bb58fde1015d5bc0c62bc3ddbb38
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gmaps
#configure api
gmaps.configure(api_key='AIzaSyAcmMgeavuweL5jD3UHoWSMhIKjxrTYzE0')
#Define location 1 and 2
Durango = (37.2753,-107.880067)
SF = (37.7749,-122.419416)
#Create the map
fig = gmaps.figure()
#create the layer
layer = gmaps.directions.Directions(Durango, SF,mode='car')
#Add the layer
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
